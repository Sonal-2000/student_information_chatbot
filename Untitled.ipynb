# %%
# libraries
import random
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense, Dropout
from keras.models import load_model
from keras.models import Sequential
import numpy as np
import pickle
import json
import nltk

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('omw-1.4')
nltk.download("punkt")
nltk.download("wordnet")


# init file
words = []
classes = []
documents = []
ignore_words = ["?", "!"]
data_file = open("pairs.json").read()
intents = json.loads(data_file)

# words
for intent in intents["intents"]:
    for pattern in intent["patterns"]:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent["tag"]))

        # adding classes to our class list
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# lemmatizer
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print(len(documents), "documents")

print(len(classes), "classes", classes)

print(len(words), "unique lemmatized words", words)


pickle.dump(words, open("words.pkl", "wb"))
pickle.dump(classes, open("classes.pkl", "wb"))

# training initializer
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:, 0])
train_y = list(training[:, 1])
print("Training data created")

# actual training
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))
model.summary()

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])

# for choosing an optimal number of training epochs to avoid underfitting or overfitting use an early stopping callback to keras
# based on either accuracy or loos monitoring. If the loss is being monitored, training comes to halt when there is an 
# increment observed in loss values. Or, If accuracy is being monitored, training comes to halt when there is decrement observed in accuracy values.

# from keras import callbacks 
# earlystopping = callbacks.EarlyStopping(monitor ="loss", mode ="min", patience = 5, restore_best_weights = True)
# callbacks =[earlystopping]

# fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save("chatbot_model.h5", hist)
print("model created")

# %%
# libraries
import random
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense, Dropout
from keras.models import load_model
from keras.models import Sequential
import numpy as np
import pickle
import json
import nltk

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# init file
words = []
classes = []
documents = []
ignore_words = ["?", "!"]
data_file = open("intents.json").read()
intents = json.loads(data_file)

# %%
# words
for intent in intents["intents"]:
    for pattern in intent["patterns"]:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent["tag"]))

        # adding classes to our class list
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %%
# lemmatizer
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print(len(documents), "documents")

print(len(classes), "classes", classes)

print(len(words), "unique lemmatized words", words)


pickle.dump(words, open("words2.pkl", "wb"))
pickle.dump(classes, open("classes2.pkl", "wb"))
# Out:
# 101 documents
# 55 classes ['AI', 'abbr', 'artificial', 'bend', 'body', 'bot1', 'breathe', 'business', 'chatbot', 'chatterbox', 'clone', 'comp', 'computer', 'control', 'cramped', 'date', 'death', 'do', 'events', 'fav', 'fight', 'goodbye', 'greetings', 'hardware', 'hobby', 'idea', 'imortal', 'lang', 'laugh', 'lie', 'machine', 'malfunction', 'motormouth', 'move', 'name', 'name1', 'need', 'noanswer', 'os', 'program', 'programming', 'ratchet', 'robotics', 'robots', 'robotss', 'sapient', 'sense', 'sentiment', 'shoe', 'sound', 'stupid', 'thanks', 'usage', 'who', 'wt']
# 141 unique lemmatized words ["'m", "'s", ',', '.', 'a', 'about', 'academic', 'admission', 'all', 'allowed', 'am', 'and', 'are', 'awesome', 'be', 'being', 'body', 'bot', 'breathe', 'business', 'bye', 'campus', 'can', 'chat', 'chatterbox', 'class', 'coffee', 'college', 'company', 'computer', 'conduct', 'control', 'cramped', 'criterion', 'data', 'date', 'die', 'do', 'doe', 'eligibility', 'event', 'favorite', 'favour', 'fee', 'fight', 'for', 'good', 'graduate', 'great', 'hardware', 'haroo', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hii', 'hobby', 'holla', 'hope', 'how', 'i', 'idea', 'in', 'invited', 'is', 'it', 'jaw', 'kind', 'language', 'later', 'lie', 'like', 'malfunction', 'me', 'mission', 'motormouth', 'move', 'my', 'name', 'need', 'not', 'of', 'okay', 'on', 'operating', 'option', 'out', 'pay', 'placement', 'popping', 'process', 'product', 'program', 'programming', 'provide', 'purpose', 'ratchet', 'really', 'recruitment', 'robot', 'robotics', 'see', 'sentient', 'shoe', 'should', 'size', 'sound', 'stupid', 'support', 'system', 'take', 'tell', 'thank', 'thanks', 'thankyou', 'that', 'the', 'there', 'to', 'true', 'type', 'upcoming', 'use', 'vision', 'walk', 'want', 'wassup', 'what', 'when', 'who', 'will', 'with', 'work', 'wow', 'written', 'wtf', 'yaw', 'you', 'your']

# %%
# training initializer
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# %%
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:, 0])
train_y = list(training[:, 1])
print("Training data created")
# Out:
# Training data created
# C:\Users\MANASI\AppData\Local\Temp/ipykernel_29324/98625446.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# actual training
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))
model.summary()

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               18176
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 55)                3575
#
# =================================================================
# Total params: 30,007
# Trainable params: 30,007
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
# for choosing an optimal number of training epochs to avoid underfitting or overfitting use an early stopping callback to keras
# based on either accuracy or loos monitoring. If the loss is being monitored, training comes to halt when there is an 
# increment observed in loss values. Or, If accuracy is being monitored, training comes to halt when there is decrement observed in accuracy values.

# from keras import callbacks 
# earlystopping = callbacks.EarlyStopping(monitor ="loss", mode ="min", patience = 5, restore_best_weights = True)
# callbacks =[earlystopping]

# fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save("chatbot_model2.h5", hist)
print("model created")
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 2ms/step - loss: 4.0323 - accuracy: 0.0198
# Epoch 2/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.9419 - accuracy: 0.0990
# Epoch 3/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.8530 - accuracy: 0.1089
# Epoch 4/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.7639 - accuracy: 0.1089
# Epoch 5/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.7168 - accuracy: 0.1188
# Epoch 6/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.6241 - accuracy: 0.1683
# Epoch 7/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.5309 - accuracy: 0.1782
# Epoch 8/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.4387 - accuracy: 0.1881
# Epoch 9/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.2100 - accuracy: 0.2376
# Epoch 10/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.2600 - accuracy: 0.1980
# Epoch 11/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.0877 - accuracy: 0.2376
# Epoch 12/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.0718 - accuracy: 0.1980
# Epoch 13/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.9518 - accuracy: 0.2772
# Epoch 14/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.8809 - accuracy: 0.2574
# Epoch 15/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.6729 - accuracy: 0.2970
# Epoch 16/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.7069 - accuracy: 0.3168
# Epoch 17/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.5962 - accuracy: 0.3564
# Epoch 18/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.5896 - accuracy: 0.3267
# Epoch 19/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.3476 - accuracy: 0.3663
# Epoch 20/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.4793 - accuracy: 0.3069
# Epoch 21/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.2962 - accuracy: 0.3762
# Epoch 22/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.1199 - accuracy: 0.4356
# Epoch 23/200
# 21/21 [==============================] - 0s 3ms/step - loss: 1.8847 - accuracy: 0.4950
# Epoch 24/200
# 21/21 [==============================] - 0s 3ms/step - loss: 2.1337 - accuracy: 0.4455
# Epoch 25/200
# 21/21 [==============================] - 0s 3ms/step - loss: 1.9286 - accuracy: 0.4752
# Epoch 26/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.9117 - accuracy: 0.4950
# Epoch 27/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.8214 - accuracy: 0.5050
# Epoch 28/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.6895 - accuracy: 0.5743
# Epoch 29/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.6831 - accuracy: 0.4950
# Epoch 30/200
# 21/21 [==============================] - 0s 3ms/step - loss: 1.8230 - accuracy: 0.4653
# Epoch 31/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.6010 - accuracy: 0.5644
# Epoch 32/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.4857 - accuracy: 0.5941
# Epoch 33/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.5715 - accuracy: 0.5644
# Epoch 34/200
# 21/21 [==============================] - 0s 3ms/step - loss: 1.4009 - accuracy: 0.6238
# Epoch 35/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.5451 - accuracy: 0.5347
# Epoch 36/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.5125 - accuracy: 0.4950
# Epoch 37/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.2833 - accuracy: 0.6337
# Epoch 38/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.1890 - accuracy: 0.6733
# Epoch 39/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.2247 - accuracy: 0.6238
# Epoch 40/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.2421 - accuracy: 0.6436
# Epoch 41/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.2998 - accuracy: 0.6535
# Epoch 42/200
# 21/21 [==============================] - 0s 3ms/step - loss: 1.2328 - accuracy: 0.6238
# Epoch 43/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.3441 - accuracy: 0.5941
# Epoch 44/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.1263 - accuracy: 0.6337
# Epoch 45/200
# 21/21 [==============================] - 0s 3ms/step - loss: 1.2948 - accuracy: 0.6040
# Epoch 46/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.7970 - accuracy: 0.7723
# Epoch 47/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.9502 - accuracy: 0.7030
# Epoch 48/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.9525 - accuracy: 0.7327
# Epoch 49/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.9449 - accuracy: 0.6832
# Epoch 50/200
# 21/21 [==============================] - 0s 3ms/step - loss: 1.1341 - accuracy: 0.6832
# Epoch 51/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.0685 - accuracy: 0.6832
# Epoch 52/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8491 - accuracy: 0.7525
# Epoch 53/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7689 - accuracy: 0.8020
# Epoch 54/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8005 - accuracy: 0.7327
# Epoch 55/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9143 - accuracy: 0.7525
# Epoch 56/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9879 - accuracy: 0.7327
# Epoch 57/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9725 - accuracy: 0.7129
# Epoch 58/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8431 - accuracy: 0.7228
# Epoch 59/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9159 - accuracy: 0.6931
# Epoch 60/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7200 - accuracy: 0.8020
# Epoch 61/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9589 - accuracy: 0.7426
# Epoch 62/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8320 - accuracy: 0.7426
# Epoch 63/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7140 - accuracy: 0.7822
# Epoch 64/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.7331 - accuracy: 0.7624
# Epoch 65/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7296 - accuracy: 0.7624
# Epoch 66/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.8119
# Epoch 67/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7516 - accuracy: 0.8218
# Epoch 68/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7709 - accuracy: 0.8020
# Epoch 69/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8621 - accuracy: 0.7426
# Epoch 70/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.8515
# Epoch 71/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8657 - accuracy: 0.6733
# Epoch 72/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6955 - accuracy: 0.8119
# Epoch 73/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5778 - accuracy: 0.8317
# Epoch 74/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8018 - accuracy: 0.7723
# Epoch 75/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.7129
# Epoch 76/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6349 - accuracy: 0.7921
# Epoch 77/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8048 - accuracy: 0.7426
# Epoch 78/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5884 - accuracy: 0.8218
# Epoch 79/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7111 - accuracy: 0.7723
# Epoch 80/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6760 - accuracy: 0.7525
# Epoch 81/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6012 - accuracy: 0.8218
# Epoch 82/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.7921
# Epoch 83/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6020 - accuracy: 0.7822
# Epoch 84/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.8020
# Epoch 85/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6151 - accuracy: 0.7921
# Epoch 86/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4496 - accuracy: 0.8713
# Epoch 87/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6316 - accuracy: 0.8218
# Epoch 88/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4874 - accuracy: 0.8119
# Epoch 89/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6083 - accuracy: 0.8416
# Epoch 90/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5208 - accuracy: 0.8119
# Epoch 91/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5825 - accuracy: 0.7921
# Epoch 92/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6127 - accuracy: 0.8218
# Epoch 93/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3803 - accuracy: 0.8911
# Epoch 94/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.8218
# Epoch 95/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5099 - accuracy: 0.8416
# Epoch 96/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.8911
# Epoch 97/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4972 - accuracy: 0.8416
# Epoch 98/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4356 - accuracy: 0.8713
# Epoch 99/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8614
# Epoch 100/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5827 - accuracy: 0.8119
# Epoch 101/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4118 - accuracy: 0.8317
# Epoch 102/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6442 - accuracy: 0.8020
# Epoch 103/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.8218
# Epoch 104/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.8515
# Epoch 105/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.7921
# Epoch 106/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5242 - accuracy: 0.8416
# Epoch 107/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4172 - accuracy: 0.8614
# Epoch 108/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.8614
# Epoch 109/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4469 - accuracy: 0.8911
# Epoch 110/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.8218
# Epoch 111/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5762 - accuracy: 0.8218
# Epoch 112/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8911
# Epoch 113/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3873 - accuracy: 0.8911
# Epoch 114/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4034 - accuracy: 0.8515
# Epoch 115/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8812
# Epoch 116/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8911
# Epoch 117/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4366 - accuracy: 0.8515
# Epoch 118/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5043 - accuracy: 0.8515
# Epoch 119/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8614
# Epoch 120/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4169 - accuracy: 0.8416
# Epoch 121/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5347 - accuracy: 0.8416
# Epoch 122/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3196 - accuracy: 0.9010
# Epoch 123/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5422 - accuracy: 0.7921
# Epoch 124/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4931 - accuracy: 0.8218
# Epoch 125/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8812
# Epoch 126/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.8713
# Epoch 127/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3369 - accuracy: 0.8713
# Epoch 128/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5184 - accuracy: 0.8317
# Epoch 129/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2524 - accuracy: 0.9208
# Epoch 130/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4936 - accuracy: 0.8515
# Epoch 131/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4286 - accuracy: 0.8515
# Epoch 132/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3697 - accuracy: 0.8812
# Epoch 133/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4309 - accuracy: 0.8911
# Epoch 134/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3019 - accuracy: 0.9307
# Epoch 135/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2972 - accuracy: 0.9406
# Epoch 136/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3220 - accuracy: 0.8812
# Epoch 137/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3585 - accuracy: 0.8911
# Epoch 138/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8614
# Epoch 139/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3194 - accuracy: 0.9307
# Epoch 140/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3873 - accuracy: 0.8713
# Epoch 141/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5516 - accuracy: 0.8515
# Epoch 142/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3827 - accuracy: 0.8713
# Epoch 143/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.8317
# Epoch 144/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3515 - accuracy: 0.8911
# Epoch 145/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8911
# Epoch 146/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6575 - accuracy: 0.8218
# Epoch 147/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8713
# Epoch 148/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.8911
# Epoch 149/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3320 - accuracy: 0.9307
# Epoch 150/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4609 - accuracy: 0.8713
# Epoch 151/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5260 - accuracy: 0.8020
# Epoch 152/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.8713
# Epoch 153/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8218
# Epoch 154/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5199 - accuracy: 0.8317
# Epoch 155/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.8515
# Epoch 156/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8614
# Epoch 157/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.8317
# Epoch 158/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4637 - accuracy: 0.8317
# Epoch 159/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8713
# Epoch 160/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8713
# Epoch 161/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5506 - accuracy: 0.8020
# Epoch 162/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.8713
# Epoch 163/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4688 - accuracy: 0.8713
# Epoch 164/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.8713
# Epoch 165/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2988 - accuracy: 0.8812
# Epoch 166/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3235 - accuracy: 0.8713
# Epoch 167/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.9010
# Epoch 168/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.9208
# Epoch 169/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4340 - accuracy: 0.8812
# Epoch 170/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8713
# Epoch 171/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3265 - accuracy: 0.8812
# Epoch 172/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2811 - accuracy: 0.9208
# Epoch 173/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2361 - accuracy: 0.9109
# Epoch 174/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.8515
# Epoch 175/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3792 - accuracy: 0.8911
# Epoch 176/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8713
# Epoch 177/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3543 - accuracy: 0.8515
# Epoch 178/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2529 - accuracy: 0.9109
# Epoch 179/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.8416
# Epoch 180/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9109
# Epoch 181/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.8317
# Epoch 182/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.9208
# Epoch 183/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4782 - accuracy: 0.8713
# Epoch 184/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8812
# Epoch 185/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3362 - accuracy: 0.8911
# Epoch 186/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3145 - accuracy: 0.8911
# Epoch 187/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3410 - accuracy: 0.8713
# Epoch 188/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.8911
# Epoch 189/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2672 - accuracy: 0.9109
# Epoch 190/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1533 - accuracy: 0.9307
# Epoch 191/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3032 - accuracy: 0.9010
# Epoch 192/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.9010
# Epoch 193/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.8713
# Epoch 194/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2725 - accuracy: 0.9010
# Epoch 195/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4535 - accuracy: 0.8416
# Epoch 196/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2827 - accuracy: 0.8614
# Epoch 197/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.8416
# Epoch 198/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 0.8614
# Epoch 199/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2555 - accuracy: 0.9307
# Epoch 200/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.8614
# model created
